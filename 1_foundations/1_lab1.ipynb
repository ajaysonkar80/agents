# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('AI_CREDITS_API')
base_url="https://api.aicredits.in/v1"
model="deepseek/deepseek-v4-flash-0731"
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-live-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(api_key=openai_api_key,base_url="https://api.aicredits.in/v1")

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="deepseek/deepseek-v4-flash-0731", messages=messages)
print(response.choices[0].message.content)
# Out:
# Did you know that octopuses have three hearts? Two pump blood to the gills, while the third pumps it to the rest of the body. And when they swim, the heart that pumps to the body actually stops beating — which is why they prefer crawling over swimming! 🐙

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model=model, messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# Did you know that octopuses have three hearts? Two pump blood to the gills, while the third pumps it to the rest of the body. And when they swim, the heart that pumps to the body actually stops beating — which is why they prefer crawling! 🐙

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Did you know that octopuses have three hearts? Two pump blood to the gills, while the third pumps it to the rest of the body. And when they swim, the heart that pumps to the body actually stops beating — which is why they prefer crawling! 🐙'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model=model, messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# Yes! Octopuses are fascinatingly weird. 🐙
#
# They have **three hearts**:
# - **Two branchial hearts** that pump blood through the gills to pick up oxygen.
# - **One systemic heart** that pumps oxygen-rich blood to the rest of the body.
#
# When they swim, the systemic heart **stops beating**, which makes swimming tiring and inefficient — so crawling is definitely their preferred travel method. Also, their blood is **blue** because it uses copper-based hemocyanin instead of iron-based hemoglobin!
#
# Nature really went all out with octopuses. 😄

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Yes! Octopuses are fascinatingly weird. 🐙
#
# They have **three hearts**:
# - **Two branchial hearts** that pump blood through the gills to pick up oxygen.
# - **One systemic heart** that pumps oxygen-rich blood to the rest of the body.
#
# When they swim, the systemic heart **stops beating**, which makes swimming tiring and inefficient — so crawling is definitely their preferred travel method. Also, their blood is **blue** because it uses copper-based hemocyanin instead of iron-based hemoglobin!
#
# Nature really went all out with octopuses. 😄

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# Did you know that octopuses have three hearts? Two pump blood to the gills, while the third pumps it to the rest of the body. And when they swim, the heart that pumps to the body actually stops beating — which is why they prefer crawling! 🐙
#
# And here is a possible answer that might be correct or incorrect:
# Yes! Octopuses are fascinatingly weird. 🐙
#
# They have **three hearts**:
# - **Two branchial hearts** that pump blood through the gills to pick up oxygen.
# - **One systemic heart** that pumps oxygen-rich blood to the rest of the body.
#
# When they swim, the systemic heart **stops beating**, which makes swimming tiring and inefficient — so crawling is definitely their preferred travel method. Also, their blood is **blue** because it uses copper-based hemocyanin instead of iron-based hemoglobin!
#
# Nature really went all out with octopuses. 😄
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model=model, messages=messages)
print(response.choices[0].message.content)
# Out:
# The answer is **correct**.
#
# It accurately states that octopuses have **three hearts**:
#
# - **Two branchial hearts** — pump blood to the gills for oxygen uptake.
# - **One systemic heart** — pumps oxygenated blood to the rest of the body.
#
# It’s also correct that the **systemic heart can stop beating when octopuses swim**, which makes swimming more exhausting and is one reason they prefer crawling.
#
# And yes, octopus blood is **blue** because it uses **copper-based hemocyanin**, not iron-based hemoglobin.
#
# So the answer is factually accurate and appropriately enthusiastic. 🐙

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "give me only one business area that might be worth exploring for an agentic ai opportunity"}]

# Then make the first call:

response = openai.chat.completions.create(model=model,messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content
print(business_area)

# And repeat! In the next message, include the business area within the message
# Out:
# **Healthcare prior authorization automation** — agentic AI can handle the entire workflow: gather clinical data, draft submissions, track status, appeal denials, and communicate with providers/payers.

# %%
message=f"""
here is a business area {business_area} and i want you to give me 
pain points of the businesses and give me the most problematic only 1 pain point only.
"""
messages = [{"role": "user", "content": message}]
response=openai.chat.completions.create(model=model,messages=messages)
single_most_problematic_pain_point=response.choices[0].message.content
print(single_most_problematic_pain_point)
# Out:
# The most problematic pain point is:
#
# **The crushing administrative burden of manual prior-authorization work.**
#
# It forces clinical staff to spend hours gathering data, completing payer-specific forms, faxing, calling, and re-submitting — pulling them away from patient care and burning them out. This hidden operational cost is the root cause of delays, denials, and revenue leakage, making it the single biggest pain point for healthcare businesses.

# %%
message=f"""
here is a The single most problematic pain point {single_most_problematic_pain_point} and i want you to give me 
give the solution of this problem with the the help of agentic ai.
"""
messages = [{"role": "user", "content": message}]
response=openai.chat.completions.create(model=model,messages=messages)
solution=response.choices[0].message.content
print(solution)
# Out:
# The solution is an **Agentic Prior-Authorization Coordinator** — an AI “digital colleague” that owns each prior-auth case from order to approval, does the manual, repetitive, payer-required work, and hands off to humans only for clinical judgment and payer conversations that require a person.
#
# ---
#
# ## What Agentic AI Means Here
#
# Agentic AI is not a chatbot and not simple RPA. It is AI that can:
#
# - **Plan** the next action
# - **Use tools** like EHR APIs, fax gateways, payer portals, and email
# - **Read unstructured data** from clinical notes, lab results, and policy PDFs
# - **Adapt** when forms change, submissions fail, or denials come back
# - **Escalate** to a human with the right context and evidence
#
# In short: it behaves like a highly organized, tireless prior-auth specialist.
#
# ---
#
# ## The Agentic Prior-Authorization Workflow
#
# ### 1. Trigger and Intake
#
# The agent fires automatically when a provider orders a medication, procedure, imaging study, or referral that requires prior auth.
#
# It captures:
#
# - Patient demographics
# - Insurance ID and policy number
# - CPT/HCPCS codes
# - ICD-10 diagnosis codes
# - Ordering provider and facility
# - Date/time of order
#
# It immediately checks whether prior auth is actually required for that payer, plan, and service.
#
# ---
#
# ### 2. Payer-Specific Requirements Discovery
#
# The agent does the research that usually takes staff 30–45 minutes:
#
# - Checks payer medical policies
# - Loads the correct prior-auth form or portal workflow
# - Identifies clinical documentation requirements
# - Flags “try-and-fail” requirements (e.g., previous conservative therapy, step therapy, first-line medication failure)
# - Determines whether the case needs peer-to-peer review or appeal if denied
#
# It keeps an internal knowledge base per payer, per plan, and per service code. When payer policies change, the agent detects updates and adjusts.
#
# ---
#
# ### 3. Clinical Evidence Gathering
#
# This is where agentic AI is dramatically better than legacy automation.
#
# The agent searches the EHR and pulls:
#
# - Progress notes and consultation reports
# - Relevant labs and radiology results
# - Medication history and allergy lists
# - Previous treatment attempts
# - Problem lists
# - Any prior auth history for the same patient/payer
#
# It can read unstructured clinician notes and extract just the evidence that matches the payer’s medical policy.
#
# For example, if a payer requires “3 months of conservative therapy before MRI,” the agent finds the physical therapy notes, dates, and response to treatment — and inserts them into the auth submission.
#
# ---
#
# ### 4. Form Completion and Submission
#
# The agent then:
#
# - Fills out the payer-specific form
# - Attaches the relevant clinical evidence
# - Enters the correct ICD-10/CPT codes
# - Writes a clinical summary in payer-friendly language
# - Submits through the best available channel:
#   - Payer API
#   - Clearinghouse
#   - Payer portal
#   - EDI 278 transaction
#   - Secure email or fax fallback
#
# It does not just “copy-paste” data. It **constructs an argument for medical necessity** based on the payer’s criteria.
#
# ---
#
# ### 5. Status Tracking and Denial Remediation
#
# The agent does not disappear after submission.
#
# It:
#
# - Tracks the auth in payer portals and batch responses
# - Checks status regularly
# - Interprets denial codes and reasons
# - Identifies missing documentation
# - Corrects the issue and resubmits
# - Generates an appeal packet if needed
# - Alerts staff when a time-sensitive deadline is near
#
# If the payer requests more information, the agent fetches it and finishes the job.
#
# ---
#
# ### 6. Human Handoff When Needed
#
# The agent knows when to stop:
#
# - If a peer-to-peer physician discussion is required, the agent schedules it and prepares a one-page clinical summary with supporting evidence.
# - If the case requires clinical judgment, it sends a human an alert with everything already organized.
# - If the payer rejects the submission for business reasons, the agent handles it automatically.
#
# Humans are no longer doing data entry. They are doing medical review and complex escalation.
#
# ---
#
# ## What This Looks Like in Practice
#
# Imagine a physician orders an MRI for a patient with an HMO plan.
#
# Before agentic AI:
#
# > A referral coordinator receives the order, checks the payer portal, prints forms, searches the EHR for “three months of PT documentation,” faxes records, waits a week, calls the payer, gets disconnected, resubmits, and finally gets approval. That takes 45–90 minutes of human time and delays care.
#
# With agentic AI:
#
# > Within seconds, the agent validates benefits, determines the MRI requires an authorization, pulls the PT notes, fills the insurer’s specific form, attaches the evidence, submits it through the portal, and updates the provider. If the payer requests more records, the agent handles it. The human staff is never pulled away from patient care.
#
# ---
#
# ## Why This Fixes the Root Problem
#
# The pain point is not “insurance companies are difficult.” The pain point is that clinical staff are doing **payer operations work** manually.
#
# Agentic AI removes that burden because it:
#
# - **Never sleeps**
# - **Never forgets** payer-specific forms or policies
# - **Never gets frustrated** by fax machines and portals
# - **Scales** with volume, not headcount
# - **Turns hidden work into visible status tracking**
# - **Prevents denials** by submitting complete, evidence-backed first requests
#
# ---
#
# ## Practical Implementation Roadmap
#
# If you want to solve this with agentic AI, do not try to boil the ocean.
#
# ### Step 1: Pick a High-Volume, High-Pain Area
#
# Choose one or two prior-auth types:
#
# - Imaging (MRI, CT, PET)
# - Infusion/biologics
# - Durable medical equipment
# - Behavioral health approvals
#
# ### Step 2: Connect the EHR and Data Sources
#
# Use FHIR, HL7, or APIs to give the agent access to:
#
# - Patient demographics
# - Orders
# - Notes
# - Labs
# - Medications
# - Problem lists
#
# ### Step 3: Build Payer Policy Knowledge
#
# For your highest-volume payers, load:
#
# - Current policy documents
# - Required forms
# - Common denial reasons
# - Authorization criteria
#
# Use LLMs to convert those documents into machine-readable decision rules.
#
# ### Step 4: Launch in “Shadow Mode”
#
# Let the agent work alongside your current staff silently.
#
# It processes the same cases, fills the same forms, and submits only after a human approves its work.
#
# Compare its output to the staff’s output:
#
# - Accuracy
# - Speed
# - Denial rate
# - Hours spent
#
# ### Step 5: Move to Semi-Autonomous Mode
#
# Once the agent is above 95% pass-lock quality, let it submit automatically for low-risk cases and still escalate for:
#
# - Peer-to-peer reviews
# - Appeals
# - Cases with ambiguous clinical notes
#
# ### Step 6: Expand Payer by Payer
#
# Grow the agent’s coverage:
#
# - Add more payers
# - Add more service types
# - Add more denial appeal workflows
#
# ---
#
# ## Guardrails and Compliance
#
# Agentic AI in healthcare must be built with hard boundaries:
#
# - **HIPAA-compliant** encryption and access controls
# - **Audit trail** for every action the agent takes
# - **Human-in-the-loop** for clinical judgment
# - **No hallucinations** on claims data — every answer must trace to a source document
# - **Payer approval/terms of use** before using portals or APIs
# - **Automatic stop** when uncertainty crosses a threshold
#
# The agent is not making medical decisions. It is doing administrative work and preparing decisions for humans.
#
# ---
#
# ## Bottom Line
#
# The single biggest pain point in healthcare operations is manual prior-authorization work. The fix is an **agentic AI prior-authorization worker** that can research, extract, submit, track, resubmit, and escalate — without burning out your clinical staff.
#
# It won’t eliminate payer complexity. But it will **absorb the administrative cost of that complexity**, so your team can go back to caring for patients and your revenue cycle stops leaking time and money.
